# %% [markdown]
# ## Advance operation with Business examples

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Matplotlib used

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 3, 5, 7, 11])

plt.plot(x, y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Simple Plot")
plt.show()

# %% [markdown]
# ## Now Pratice

# %%
# Data structure: [restaurant_id, 2021, 2022, 2023, 2024]
sales_data = np.array([
    [1, 150000, 180000, 220000, 250000],  # Paradise Biryani
    [2, 120000, 140000, 160000, 190000],  # Beijing Bites
    [3, 200000, 230000, 260000, 300000],  # Pizza Hub
    [4, 180000, 210000, 240000, 270000],  # Burger Point
    [5, 160000, 185000, 205000, 230000]   # Chai Point
])

print("==== Zomato sales analysis ==== ")
print("\n Sales data shape", sales_data.shape)
print("\n Sample data for 1st 3 restau: ", sales_data[:3])
print("\n Sales data (2021-2024): ", sales_data[:, 1:])
# Out:
# ==== Zomato sales analysis ====
#
#  Sales data shape (5, 5)
#
#  Sample data for 1st 3 restau:  [[     1 150000 180000 220000 250000]
#  [     2 120000 140000 160000 190000]
#  [     3 200000 230000 260000 300000]]
#
#  Sales data (2021-2024):  [[150000 180000 220000 250000]
#  [120000 140000 160000 190000]
#  [200000 230000 260000 300000]
#  [180000 210000 240000 270000]
#  [160000 185000 205000 230000]]

# %% [markdown]
# ## Total sum

# %%
# total sales per year
print("Total sales (2021-2024): ", np.sum(sales_data, axis=0))
year_total = np.sum(sales_data[:, 1:], axis=0)
print("Total sales per year: ", year_total)
# total sales per restaurant
print("Total sales per restaurant : ",np.sum(sales_data[:, 1:], axis=1))

print("Overall total sales : ", sum(year_total))
# Out:
# Total sales (2021-2024):  [     15  810000  945000 1085000 1240000]
# Total sales per year:  [ 810000  945000 1085000 1240000]
# Total sales per restaurant :  [800000 610000 990000 900000 780000]
# Overall total sales :  4080000

# %% [markdown]
# ### Avg, min, max

# %%
# Minimum sales per restaurant
min_sales = np.min(sales_data[:, 1:], axis=1)
print("Minimum sales per restaurant: ", min_sales)

# Maximum sales per year
max_sales = np.max(sales_data[:, 1:], axis=0)
print("Maximum sales per year: ", max_sales)

# Average sales per restaurant
avg_sales = np.mean(sales_data[:, 1:], axis=1)
print("Average of sales per restaurant: ", avg_sales)
# Out:
# Minimum sales per restaurant:  [150000 120000 200000 180000 160000]
# Maximum sales per year:  [200000 230000 260000 300000]
# Average of sales per restaurant:  [200000. 152500. 247500. 225000. 195000.]

# %%
cumsum = np.cumsum(sales_data[:, 1:], axis=1)
print(cumsum)

plt.figure(figsize=(8, 6))
plt.plot(np.mean(cumsum, axis=0))
plt.title("Average cumulative sales across all restaurants")
plt.xlabel("Years")
plt.ylabel("Sales")
plt.grid(True)
plt.show()
# Out:
# [[150000 330000 550000 800000]
#  [120000 260000 420000 610000]
#  [200000 430000 690000 990000]
#  [180000 390000 630000 900000]
#  [160000 345000 550000 780000]]

# %% [markdown]
# ## Vector

# %%
vector1 = np.array([1, 2, 3, 4, 5])
vector2 = np.array([6, 7, 8, 9, 10])

print("Vector addition: ", vector1 + vector2)

print("\n Multiplication vector", vector1 * vector2)

print("\nDot Product", np.dot(vector1, vector2))

angle = np.arccos(np.dot(vector1, vector2) / (np.linalg.norm(vector1) * np.linalg.norm(vector2)))
print(angle)
# Out:
# Vector addition:  [ 7  9 11 13 15]
#
#  Multiplication vector [ 6 14 24 36 50]
#
# Dot Product 130
# 0.26554161733900966

# %%
vector3 = np.array([[1,4],[2,5],[3,6]])
print("Vector 3: ", vector3)
vector4 = np.array([[2,3]])
print("Vector 4: ", vector4)
multi = vector3 * vector4
print("\n Multiplication vector", multi)
print("\n vector multiplication addition: ", np.sum(multi, axis=1))

#dot
dot_product = np.dot(vector3, vector4.T)
print("\n Dot Product: ", dot_product)
# Out:
# Vector 3:  [[1 4]
#  [2 5]
#  [3 6]]
# Vector 4:  [[2 3]]
#
#  Multiplication vector [[ 2 12]
#  [ 4 15]
#  [ 6 18]]
#
#  vector multiplication addition:  [14 19 24]
#
#  Dot Product:  [[14]
#  [19]
#  [24]]

# %%
restaurant_types = np.array(['biryani', 'chinese', 'pizza', 'burger', 'cafe'])
vectorized_upper = np.vectorize(str.upper)
print("Vectorized Upper", vectorized_upper(restaurant_types))

#graph
plt.figure(figsize=(8, 5))
plt.bar(restaurant_types, vectorized_upper(restaurant_types))
plt.title('Restaurant Types')
plt.xlabel('Types')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid()
plt.show()
# Out:
# Vectorized Upper ['BIRYANI' 'CHINESE' 'PIZZA' 'BURGER' 'CAFE']

# %%
monthly_avg = sales_data[:, 1:] / 12

# print(monthly_avg)
print("Monthly Average Sales: \n", np.round(monthly_avg, 2))

#graph
plt.figure(figsize=(6, 5))
plt.plot(monthly_avg.T, marker='o')
plt.title('Monthly Average Sales')
plt.xlabel('Months')
plt.ylabel('Sales')
plt.xticks(ticks=np.arange(12), labels=[
    'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
    'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'
])
plt.legend(['Product A', 'Product B', 'Product C'])
plt.grid()
plt.show()
# Out:
# Monthly Average Sales:
#  [[12500.   15000.   18333.33 20833.33]
#  [10000.   11666.67 13333.33 15833.33]
#  [16666.67 19166.67 21666.67 25000.  ]
#  [15000.   17500.   20000.   22500.  ]
#  [13333.33 15416.67 17083.33 19166.67]]

# %% [markdown]
# ## Vector angle

# %%
#vector angle
vector1 = np.array([1, 2, 3])
vector2 = np.array([4, 5, 6])
cosine_similarity = np.dot(vector1, vector2) / (np.linalg.norm(vector1) * np.linalg.norm(vector2))
print("Cosine Similarity: ", cosine_similarity)

#graph
plt.figure(figsize=(6, 5))
plt.bar(['Vector 1', 'Vector 2'], [np.linalg.norm(vector1), np.linalg.norm(vector2)], color=['blue', 'orange'])
plt.title('Vector Magnitudes')
plt.xlabel('Vectors')
plt.ylabel('Magnitude')
plt.grid()
plt.show()
# Out:
# Cosine Similarity:  0.9746318461970762
